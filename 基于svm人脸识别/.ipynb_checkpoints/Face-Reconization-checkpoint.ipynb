# %% [markdown]
# ## 人脸识别
# 1. 人脸有不同的颜色组成
# 2. 不同的颜色由三原色：红绿蓝组成
# 3. 红绿蓝由0~255的数字组成
#
# ### 所以人脸是由数据组成的

# %% [markdown]
# ### 使用matplotlib.pyplot导入数据图片并显示,观察这张图片的数据类型

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.svm import SVC

from sklearn.decomposition import PCA

# 删选合适的参数
from sklearn.model_selection import GridSearchCV

import sklearn.datasets as datasets

import logging

# %% [markdown]
# ## 进行人脸识别操作
# 1.导入相应模块工具：GridSearchCV、fetch_lfw_people、PCA、loggin等
#
#
# 2.设置logging，控制台显示程序处理数据的进度
#
#
# 3.使用fetch_lfw_people导入数据，如果本地没有会从网络下载，如果本地有数据，加载本地
#
#
# 4.查看人脸数据结构
#
#
# 5.从人脸数据中提取进行机器学习的关键数据
#
#
# 6.对数据进行分割，获取训练数据和测试数据
#
#
# 7.数据太复杂了，使用PCA对数据进行降维处理，去除一些不重要的数据
#
#
# 8.使用GridSerchCV查询最佳的机器学习模型
#
#
# 9.定义方法获取预测人名和真实人名
#
#
# 10.定义方法绘制人脸识别结果图形
#
#
# 11.调用方法进行数据展示

# %% [markdown]
# 导入相应模块工具：GridSearchCV、fetch_lfw_people、PCA、logging等

# %% [markdown]
# 设置logging.basicConfig(level=logging.INFO, format='%(asctime)s %(message)s')
# 控制台输出记录数据，显示程序处理数据的进度

# %%
# Info warning error……
logging.basicConfig(level = logging.INFO,format = '%(asctime)s%(message)s')

# %%
# lfw label face wild
faces = datasets.fetch_lfw_people(resize = 1,min_faces_per_person=70)
faces
# Out:
# {'data': array([[253.66667 , 253.66667 , 254.66667 , ...,  86.666664,  86.333336,
#           86.333336],
#         [ 42.      ,  34.      ,  31.666666, ..., 121.666664, 148.      ,
#          185.33333 ],
#         [ 94.      ,  72.      ,  74.      , ..., 182.66667 , 183.      ,
#          182.33333 ],
#         ...,
#         [ 84.333336,  86.      ,  85.333336, ...,  44.      ,  35.666668,
#           30.333334],
#         [ 49.666668,  50.333332,  47.666668, ..., 178.66667 , 167.66667 ,
#          127.333336],
#         [ 31.333334,  33.333332,  26.666666, ...,  47.666668,  63.      ,
#           99.      ]], dtype=float32),
#  'images': array([[[253.66667 , 253.66667 , 254.66667 , ...,  42.333332,
#            37.666668,  39.      ],
#          [254.      , 254.      , 253.66667 , ...,  43.333332,
#            38.      ,  39.      ],
#          [254.66667 , 254.33333 , 253.33333 , ...,  44.      ,
#            38.666668,  38.      ],
#          ...,
#          [ 68.333336,  63.333332,  51.      , ...,  90.333336,
#            85.666664,  83.666664],
#          [ 64.      ,  61.333332,  51.666668, ...,  88.      ,
#            87.      ,  87.      ],
#          [ 58.666668,  58.      ,  53.      , ...,  86.666664,
#            86.333336,  86.333336]],
#
#         [[ 42.      ,  34.      ,  31.666666, ...,  41.333332,
#            34.      ,  29.666666],
#          [ 41.666668,  35.666668,  38.      , ...,  42.      ,
#            36.      ,  33.666668],
#          [ 41.      ,  43.      ,  47.333332, ...,  48.666668,
#            46.      ,  39.666668],
#          ...,
#          [ 77.333336,  77.666664,  75.666664, ..., 110.333336,
#           110.666664, 133.33333 ],
#          [ 77.666664,  78.666664,  78.333336, ..., 112.333336,
#           123.666664, 154.66667 ],
#          [ 77.      ,  76.666664,  76.666664, ..., 121.666664,
#           148.      , 185.33333 ]],
#
#         [[ 94.      ,  72.      ,  74.      , ..., 151.66667 ,
#           150.33333 , 150.      ],
#          [ 96.      ,  88.333336,  96.      , ..., 149.66667 ,
#           148.33333 , 148.      ],
#          [ 97.333336,  86.666664,  97.666664, ..., 147.66667 ,
#           145.33333 , 147.33333 ],
#          ...,
#          [ 77.      ,  72.666664,  67.      , ..., 184.33333 ,
#           183.      , 181.      ],
#          [ 83.      ,  80.666664,  72.333336, ..., 184.      ,
#           184.      , 182.      ],
#          [ 88.333336,  86.666664,  82.666664, ..., 182.66667 ,
#           183.      , 182.33333 ]],
#
#         ...,
#
#         [[ 84.333336,  86.      ,  85.333336, ...,  37.333332,
#            42.666668,  48.      ],
#          [ 86.      ,  87.      ,  84.666664, ...,  34.333332,
#            38.333332,  43.666668],
#          [ 89.      ,  90.      ,  85.333336, ...,  33.      ,
#            37.      ,  41.      ],
#          ...,
#          [ 80.666664,  86.666664,  85.666664, ...,  58.666668,
#            55.      ,  45.666668],
#          [ 72.666664,  79.333336,  81.666664, ...,  51.      ,
#            46.      ,  36.666668],
#          [ 66.666664,  69.666664,  74.      , ...,  44.      ,
#            35.666668,  30.333334]],
#
#         [[ 49.666668,  50.333332,  47.666668, ..., 157.      ,
#           150.33333 , 140.      ],
#          [ 46.333332,  49.      ,  50.666668, ..., 159.      ,
#           154.      , 145.33333 ],
#          [ 50.666668,  51.      ,  55.666668, ..., 156.33333 ,
#           156.      , 151.      ],
#          ...,
#          [ 61.333332,  60.333332,  63.      , ..., 168.33333 ,
#           173.33333 , 169.      ],
#          [ 61.333332,  60.333332,  63.      , ..., 179.      ,
#           176.      , 153.      ],
#          [ 62.      ,  60.      ,  61.666668, ..., 178.66667 ,
#           167.66667 , 127.333336]],
#
#         [[ 31.333334,  33.333332,  26.666666, ...,  48.333332,
#            48.      ,  51.333332],
#          [ 37.      ,  27.333334,  24.333334, ...,  47.333332,
#            45.      ,  51.333332],
#          [ 35.      ,  28.      ,  23.333334, ...,  40.666668,
#            39.      ,  43.333332],
#          ...,
#          [ 43.333332,  41.333332,  41.666668, ...,  37.666668,
#            49.666668,  61.      ],
#          [ 47.      ,  46.      ,  50.666668, ...,  44.      ,
#            61.333332,  84.333336],
#          [ 46.      ,  46.      ,  46.666668, ...,  47.666668,
#            63.      ,  99.      ]]], dtype=float32),
#  'target': array([5, 6, 3, ..., 5, 3, 5], dtype=int64),
#  'target_names': array(['Ariel Sharon', 'Colin Powell', 'Donald Rumsfeld', 'George W Bush',
#         'Gerhard Schroeder', 'Hugo Chavez', 'Tony Blair'], dtype='<U17'),
#  'DESCR': 'LFW faces dataset'}

# %%
faces['images'].shape
# Out:
# (1288, 125, 94)

# %%
faces['target_names']
# Out:
# array(['Ariel Sharon', 'Colin Powell', 'Donald Rumsfeld', 'George W Bush',
#        'Gerhard Schroeder', 'Hugo Chavez', 'Tony Blair'], dtype='<U17')

# %%
index= np.random.randint(1288,size = 1)[0]

plt.figure(figsize=(2,2))

plt.imshow(faces['images'][index],cmap = 'gray')

# %% [markdown]
# 使用fetch_lfw_people导入数据，如果本地没有会从网络下载，如果本地有数据，加载本地

# %%
faces['images'].shape
# 125人脸高度，宽度94
# Out:
# (1288, 125, 94)

# %% [markdown]
# 查看人脸数据结构

# %%
# shape(125,94)
X = faces['data']

y = faces['target']

target_names = faces['target_names']

# %% [markdown]
# 从人脸数据中提取进行机器学习的关键数据

# %%
X
# Out:
# array([[253.66667 , 253.66667 , 254.66667 , ...,  86.666664,  86.333336,
#          86.333336],
#        [ 42.      ,  34.      ,  31.666666, ..., 121.666664, 148.      ,
#         185.33333 ],
#        [ 94.      ,  72.      ,  74.      , ..., 182.66667 , 183.      ,
#         182.33333 ],
#        ...,
#        [ 84.333336,  86.      ,  85.333336, ...,  44.      ,  35.666668,
#          30.333334],
#        [ 49.666668,  50.333332,  47.666668, ..., 178.66667 , 167.66667 ,
#         127.333336],
#        [ 31.333334,  33.333332,  26.666666, ...,  47.666668,  63.      ,
#          99.      ]], dtype=float32)

# %%
X.shape
# 取出来比较重要的300个特征
# 数据的特征值，计算
# 100,99，……0.1,0.01，0.0001
# 特征权重90%
# 累加和
# np.cumsum()/np.sum() > 0.9
# Out:
# (1288, 11750)

# %% [markdown]
# # PCA 降维
# 主成分分析（Principal Components Analysis），简称PCA，是一种数据降维技术，用于数据预处理。一般我们获取的原始数据维度都很高，比如1000个特征，在这1000个特征中可能包含了很多无用的信息或者噪声，真正有用的特征才100个，那么我们可以运用PCA算法将1000个特征降到100个特征。这样不仅可以去除无用的噪声，还能减少很大的计算量。
# 原始数据集dataMat 行代表样本,列代表特征
# 1)零均值化,行代表样本,列代表特征,
# 零均值化就是求每一列的平均值,然后该列上的所有数都减去这个均值
# menaVal = np.mean(dataMat,axis = 0)#按列求均值,即求各个特征的均值
# newData = dataMat - meanVal
# 2)求协方差矩阵
# covMat = np.cov(newData,rowvar = 0)
# rowvar = 0 传入的数据一行代表一份样本
# 若非0 说明传入的数据一列代表一个样本
# 3)求特征值,特征矩阵
# eigVals,eigVects = np.linalg.eig(covMat)
# eigVals存放特征值,行向量
# eigVects 存放特征向量,每一列代表一个特征向量
# 特征值和特征向量是一一对应的
# 4)保留主要成分[即保留值比较大的前n个特征]
#     -第三步得到的特征值向量eigVals,对其从小到大排序,np.argsort(eigVals)
#     -取出排在前面最大的n个特征向量(根据下表取),
#      它们组成了一个新的特征空间的一组基n_eigVect.
#     -将零均值化后的数据乘以n_eigVect就可以得到降维后的数据lowDDataMat
#     -重构数据:乘以n_eigVect的转置矩阵,再加上均值meanVal
#     (eigValIndice=np.argsort(eigVals)            #对特征值从小到大排序
#      n_eigValIndice=eigValIndice[-1:-(n+1):-1]   #最大的n个特征值的下标
#      n_eigVect=eigVects[:,n_eigValIndice]        #最大的n个特征值对应的特征向量
#      lowDDataMat=newData*n_eigVect               #低维特征空间的数据
#      reconMat=(lowDDataMat*n_eigVect.T)+meanVal  #重构数据  )
# *)如何选择主成分个数,降到几维数据,即n取多少合适,
#     一般通过方差百分比实现.(特征值从大到小排列,前n个求和/总和 >0.99)
#     (def percentage2n(eigVals,percentage):
#     sortArray=np.sort(eigVals)   #升序
#     sortArray=sortArray[-1::-1]  #逆转，即降序
#     arraySum=sum(sortArray)
#     tmpSum=0
#     num=0
#     for i in sortArray:
#         tmpSum+=i
#         num+=1
#         if tmpSum>=arraySum*percentage:
#             return num )

# %%
iris = datasets.load_iris()['data']
iris
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2],
#        [5.4, 3.9, 1.7, 0.4],
#        [4.6, 3.4, 1.4, 0.3],
#        [5. , 3.4, 1.5, 0.2],
#        [4.4, 2.9, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [5.4, 3.7, 1.5, 0.2],
#        [4.8, 3.4, 1.6, 0.2],
#        [4.8, 3. , 1.4, 0.1],
#        [4.3, 3. , 1.1, 0.1],
#        [5.8, 4. , 1.2, 0.2],
#        [5.7, 4.4, 1.5, 0.4],
#        [5.4, 3.9, 1.3, 0.4],
#        [5.1, 3.5, 1.4, 0.3],
#        [5.7, 3.8, 1.7, 0.3],
#        [5.1, 3.8, 1.5, 0.3],
#        [5.4, 3.4, 1.7, 0.2],
#        [5.1, 3.7, 1.5, 0.4],
#        [4.6, 3.6, 1. , 0.2],
#        [5.1, 3.3, 1.7, 0.5],
#        [4.8, 3.4, 1.9, 0.2],
#        [5. , 3. , 1.6, 0.2],
#        [5. , 3.4, 1.6, 0.4],
#        [5.2, 3.5, 1.5, 0.2],
#        [5.2, 3.4, 1.4, 0.2],
#        [4.7, 3.2, 1.6, 0.2],
#        [4.8, 3.1, 1.6, 0.2],
#        [5.4, 3.4, 1.5, 0.4],
#        [5.2, 4.1, 1.5, 0.1],
#        [5.5, 4.2, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [5. , 3.2, 1.2, 0.2],
#        [5.5, 3.5, 1.3, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [4.4, 3. , 1.3, 0.2],
#        [5.1, 3.4, 1.5, 0.2],
#        [5. , 3.5, 1.3, 0.3],
#        [4.5, 2.3, 1.3, 0.3],
#        [4.4, 3.2, 1.3, 0.2],
#        [5. , 3.5, 1.6, 0.6],
#        [5.1, 3.8, 1.9, 0.4],
#        [4.8, 3. , 1.4, 0.3],
#        [5.1, 3.8, 1.6, 0.2],
#        [4.6, 3.2, 1.4, 0.2],
#        [5.3, 3.7, 1.5, 0.2],
#        [5. , 3.3, 1.4, 0.2],
#        [7. , 3.2, 4.7, 1.4],
#        [6.4, 3.2, 4.5, 1.5],
#        [6.9, 3.1, 4.9, 1.5],
#        [5.5, 2.3, 4. , 1.3],
#        [6.5, 2.8, 4.6, 1.5],
#        [5.7, 2.8, 4.5, 1.3],
#        [6.3, 3.3, 4.7, 1.6],
#        [4.9, 2.4, 3.3, 1. ],
#        [6.6, 2.9, 4.6, 1.3],
#        [5.2, 2.7, 3.9, 1.4],
#        [5. , 2. , 3.5, 1. ],
#        [5.9, 3. , 4.2, 1.5],
#        [6. , 2.2, 4. , 1. ],
#        [6.1, 2.9, 4.7, 1.4],
#        [5.6, 2.9, 3.6, 1.3],
#        [6.7, 3.1, 4.4, 1.4],
#        [5.6, 3. , 4.5, 1.5],
#        [5.8, 2.7, 4.1, 1. ],
#        [6.2, 2.2, 4.5, 1.5],
#        [5.6, 2.5, 3.9, 1.1],
#        [5.9, 3.2, 4.8, 1.8],
#        [6.1, 2.8, 4. , 1.3],
#        [6.3, 2.5, 4.9, 1.5],
#        [6.1, 2.8, 4.7, 1.2],
#        [6.4, 2.9, 4.3, 1.3],
#        [6.6, 3. , 4.4, 1.4],
#        [6.8, 2.8, 4.8, 1.4],
#        [6.7, 3. , 5. , 1.7],
#        [6. , 2.9, 4.5, 1.5],
#        [5.7, 2.6, 3.5, 1. ],
#        [5.5, 2.4, 3.8, 1.1],
#        [5.5, 2.4, 3.7, 1. ],
#        [5.8, 2.7, 3.9, 1.2],
#        [6. , 2.7, 5.1, 1.6],
#        [5.4, 3. , 4.5, 1.5],
#        [6. , 3.4, 4.5, 1.6],
#        [6.7, 3.1, 4.7, 1.5],
#        [6.3, 2.3, 4.4, 1.3],
#        [5.6, 3. , 4.1, 1.3],
#        [5.5, 2.5, 4. , 1.3],
#        [5.5, 2.6, 4.4, 1.2],
#        [6.1, 3. , 4.6, 1.4],
#        [5.8, 2.6, 4. , 1.2],
#        [5. , 2.3, 3.3, 1. ],
#        [5.6, 2.7, 4.2, 1.3],
#        [5.7, 3. , 4.2, 1.2],
#        [5.7, 2.9, 4.2, 1.3],
#        [6.2, 2.9, 4.3, 1.3],
#        [5.1, 2.5, 3. , 1.1],
#        [5.7, 2.8, 4.1, 1.3],
#        [6.3, 3.3, 6. , 2.5],
#        [5.8, 2.7, 5.1, 1.9],
#        [7.1, 3. , 5.9, 2.1],
#        [6.3, 2.9, 5.6, 1.8],
#        [6.5, 3. , 5.8, 2.2],
#        [7.6, 3. , 6.6, 2.1],
#        [4.9, 2.5, 4.5, 1.7],
#        [7.3, 2.9, 6.3, 1.8],
#        [6.7, 2.5, 5.8, 1.8],
#        [7.2, 3.6, 6.1, 2.5],
#        [6.5, 3.2, 5.1, 2. ],
#        [6.4, 2.7, 5.3, 1.9],
#        [6.8, 3. , 5.5, 2.1],
#        [5.7, 2.5, 5. , 2. ],
#        [5.8, 2.8, 5.1, 2.4],
#        [6.4, 3.2, 5.3, 2.3],
#        [6.5, 3. , 5.5, 1.8],
#        [7.7, 3.8, 6.7, 2.2],
#        [7.7, 2.6, 6.9, 2.3],
#        [6. , 2.2, 5. , 1.5],
#        [6.9, 3.2, 5.7, 2.3],
#        [5.6, 2.8, 4.9, 2. ],
#        [7.7, 2.8, 6.7, 2. ],
#        [6.3, 2.7, 4.9, 1.8],
#        [6.7, 3.3, 5.7, 2.1],
#        [7.2, 3.2, 6. , 1.8],
#        [6.2, 2.8, 4.8, 1.8],
#        [6.1, 3. , 4.9, 1.8],
#        [6.4, 2.8, 5.6, 2.1],
#        [7.2, 3. , 5.8, 1.6],
#        [7.4, 2.8, 6.1, 1.9],
#        [7.9, 3.8, 6.4, 2. ],
#        [6.4, 2.8, 5.6, 2.2],
#        [6.3, 2.8, 5.1, 1.5],
#        [6.1, 2.6, 5.6, 1.4],
#        [7.7, 3. , 6.1, 2.3],
#        [6.3, 3.4, 5.6, 2.4],
#        [6.4, 3.1, 5.5, 1.8],
#        [6. , 3. , 4.8, 1.8],
#        [6.9, 3.1, 5.4, 2.1],
#        [6.7, 3.1, 5.6, 2.4],
#        [6.9, 3.1, 5.1, 2.3],
#        [5.8, 2.7, 5.1, 1.9],
#        [6.8, 3.2, 5.9, 2.3],
#        [6.7, 3.3, 5.7, 2.5],
#        [6.7, 3. , 5.2, 2.3],
#        [6.3, 2.5, 5. , 1.9],
#        [6.5, 3. , 5.2, 2. ],
#        [6.2, 3.4, 5.4, 2.3],
#        [5.9, 3. , 5.1, 1.8]])

# %%
iris.mean(axis = 0)
# Out:
# array([5.84333333, 3.054     , 3.75866667, 1.19866667])

# %%
B = iris - iris.mean(axis = 0)

# %%
# 求解协方差
C = np.cov(B,rowvar=False)
C.shape
C
# Out:
# array([[ 0.68569351, -0.03926846,  1.27368233,  0.5169038 ],
#        [-0.03926846,  0.18800403, -0.32171275, -0.11798121],
#        [ 1.27368233, -0.32171275,  3.11317942,  1.29638747],
#        [ 0.5169038 , -0.11798121,  1.29638747,  0.58241432]])

# %%
np.linalg.eigvals(C)
# Out:
# array([4.22484077, 0.24224357, 0.07852391, 0.02368303])

# %%
T,T_ = np.linalg.eig(C)

# %%
T,T_ = np.linalg.eig(C)

# %%
T_[:,:2]
# Out:
# array([[ 0.36158968, -0.65653988],
#        [-0.08226889, -0.72971237],
#        [ 0.85657211,  0.1757674 ],
#        [ 0.35884393,  0.07470647]])

# %%
D = iris.dot(T_[:,:2])

# %%
pca = PCA(2)
pca.fit_transform(iris)
pca.get_covariance()
# Out:
# array([[ 0.67919741, -0.03258618,  1.27066452,  0.5321852 ],
#        [-0.03258618,  0.18113034, -0.31863564, -0.13363564],
#        [ 1.27066452, -0.31863564,  3.11934547,  1.28541527],
#        [ 0.5321852 , -0.13363564,  1.28541527,  0.58961806]])

# %%
pca.explained_variance_
# Out:
# array([4.22484077, 0.24224357])

# %%
pca.explained_variance_ratio_
# Out:
# array([0.92461621, 0.05301557])

# %%
pca.get_precision()
# Out:
# array([[10.38525514, -6.82204502, -4.20572606, -1.7510368 ],
#        [-6.82204502, 11.21577598,  3.34261   ,  1.41240052],
#        [-4.20572606,  3.34261   ,  4.90734692, -6.14476038],
#        [-1.7510368 ,  1.41240052, -6.14476038, 16.99268128]])

# %%
D - D.mean(axis = 0)/D.std(axis = 0)
# Out:
# array([[ 1.36810828e-01,  5.19312367e+00],
#        [ 1.05627338e-01,  5.68928783e+00],
#        [ 4.07864314e+00,  5.69886798e+00],
#        [ 4.11168760e+00,  5.63615624e+00],
#        [ 4.94387193e+00,  5.73058587e+00],
#        [ 5.20858236e+00,  5.05721174e+00],
#        [ 5.66197888e+00,  5.14698840e+00],
#        [ 6.05336085e+00,  4.14920695e+00],
#        [ 4.97975633e+00,  5.73805652e+00],
#        [ 4.26412056e+00,  5.66353228e+00],
#        [ 4.60065806e+00,  6.02119578e+00],
#        [ 5.89753957e+00,  4.83396654e+00],
#        [ 4.96600481e+00,  5.38082438e+00],
#        [ 4.72588088e+00,  5.47168348e+00],
#        [ 3.98987142e+00,  5.68423349e+00],
#        [ 4.92867168e+00,  5.14824874e+00],
#        [ 5.13532135e+00,  5.33712214e+00],
#        [ 4.74346884e+00,  5.11045981e+00],
#        [ 4.23509018e+00,  6.09465604e+00],
#        [ 5.38434067e+00,  5.24375648e+00],
#        [ 5.24040917e+00,  5.21622705e+00],
#        [ 4.76503500e+00,  5.33231576e+00],
#        [ 4.34668158e+00,  5.89475183e+00],
#        [ 4.58506389e+00,  5.44121180e+00],
#        [ 4.72264703e+00,  5.40385424e+00],
#        [ 4.21068409e+00,  5.80261770e+00]])

# %%
np.linalg.eigh(C)
# Out:
# (array([0.02368303, 0.07852391, 0.24224357, 4.22484077]),
#  array([[ 0.31725455,  0.58099728,  0.65653988, -0.36158968],
#         [-0.32409435, -0.59641809,  0.72971237,  0.08226889],
#         [-0.47971899, -0.07252408, -0.1757674 , -0.85657211],
#         [ 0.75112056, -0.54906091, -0.07470647, -0.35884393]]))

# %%
np.linalg.eigvalsh(C)
# Out:
# array([0.02368303, 0.07852391, 0.24224357, 4.22484077])

# %% [markdown]
# 分割训练数据和预测数据

# %% [markdown]
# 使用PCA进行降维

# %%
pca = PCA(n_components=300,whiten=True)

pca.fit(X)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=300, random_state=None,
#   svd_solver='auto', tol=0.0, whiten=True)

# %%
X_pca = pca.transform(X)
X_pca.shape
# Out:
# (1288, 300)

# %%
# 约等于0
X_pca.mean(axis = 0)
# Out:
# array([ 1.97556076e-07,  1.00015946e-07, -1.30500855e-08,  2.48969716e-08,
#         4.62768990e-11,  1.70946862e-07,  2.13151395e-07,  6.97994437e-07,
#         8.05102331e-08,  1.49219858e-07, -1.22344552e-08,  3.88725958e-08,
#         1.60025508e-07, -6.07893355e-07,  3.26240553e-07, -2.02530842e-07,
#        -4.04367540e-07, -1.88346974e-07,  4.37663772e-08,  5.80942810e-07,
#         3.15932397e-07, -4.98587326e-07, -5.44910472e-09,  1.44754139e-07,
#        -3.66420466e-07, -2.33721480e-07, -2.87842301e-08, -3.02616201e-07,
#         5.10387906e-07, -6.37371727e-07,  9.71814842e-08,  2.59520846e-07,
#        -8.99160142e-08, -4.39954476e-07,  2.98208334e-07,  4.78364313e-07,
#         4.55734892e-07, -3.86504666e-07,  7.13127008e-07,  1.50168535e-08,
#        -5.57914291e-07, -1.46142440e-07, -6.47089848e-07,  1.22911445e-07,
#         9.24485164e-07,  7.65882646e-09,  7.52929452e-07,  3.83681765e-07,
#        0.9996114 , 0.99961174, 0.999612  , 0.9996115 , 0.99961156,
#        0.9996112 , 0.99961185, 0.99961096, 0.99961144, 0.9996122 ,
#        0.99961156, 0.9996118 , 0.9996117 , 0.99961245, 0.9996118 ,
#        0.99961185, 0.9996113 , 0.99961114, 0.9996121 , 0.9996119 ,
#        0.999612  , 0.99961156, 0.99961174, 0.999612  , 0.9996111 ,
#        0.99961126, 0.99961126, 0.99961126, 0.9996115 , 0.9996116 ,
#        0.99961185, 0.9996113 , 0.999611  , 0.99961144, 0.99961156,
#        0.99961144, 0.9996109 , 0.9996114 , 0.9996117 , 0.9996111 ,
#        0.99961126, 0.9996118 , 0.9996121 , 0.99961203, 0.9996117 ,
#        0.9996119 , 0.9996117 , 0.99961156, 0.99961215, 0.9996121 ,
#        0.9996118 , 0.99961215, 0.999612  , 0.9996118 , 0.99961185,
#        0.9996122 , 0.99961203, 0.9996118 , 0.99961144, 0.9996112 ,
#        0.99961203, 0.99961156, 0.9996118 , 0.9996122 , 0.9996117 ],
#       dtype=float32)

# %%
from sklearn.model_selection import train_test_split

# %%
# X_train,X_test,画图方便保留的数据
X_train,X_test,X_train_pca,X_test_pca,y_train,y_test = train_test_split(X,X_pca,y,test_size = 0.2)

# %% [markdown]
# 使用GridSearchCV我们找到了最佳的支持向量机方法

# %%
C = [0.001,0.1,1,5,10]
'''gamma : float, optional (default='auto')
    Kernel coefficient for 'rbf', 'poly' and 'sigmoid'.
    If gamma is 'auto' then 1/n_features will be used instead.'''
# X_pca 特征300  1/300 = 0.0033
gamma = [0.0001,0.0002,0.0033,0.01,0.1]
# 5 * 5 = 25
svc = SVC()

# 交叉验证，可以将参数交叉，验证
gcv = GridSearchCV(svc,param_grid={'C':C,'gamma':gamma})

# %%
# %time gcv.fit(X_train_pca,y_train)
# Out:
# Wall time: 44.7 s
# GridSearchCV(cv=None, error_score='raise',
#        estimator=SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False),
#        fit_params=None, iid=True, n_jobs=1,
#        param_grid={'C': [0.001, 0.1, 1, 5, 10], 'gamma': [0.0001, 0.0002, 0.0033, 0.01, 0.1]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=None, verbose=0)

# %%
gcv.best_params_
# Out:
# {'C': 10, 'gamma': 0.0002}

# %%
gcv.best_score_
# Out:
# 0.7271844660194174

# %% [markdown]
# 进行数据预测

# %%
y_ = gcv.predict(X_test_pca)
y_
# Out:
# array([1, 2, 3, 3, 1, 6, 1, 3, 3, 3, 1, 3, 3, 3, 4, 6, 3, 3, 6, 3, 3, 3,
#        2, 6, 6, 3, 1, 3, 1, 0, 3, 3, 6, 6, 1, 1, 4, 3, 3, 3, 3, 3, 0, 3,
#        3, 1, 6, 4, 4, 3, 3, 3, 3, 1, 3, 3, 3, 3, 3, 6, 3, 3, 2, 3, 1, 1,
#        3, 3, 3, 2, 3, 3, 3, 3, 1, 4, 4, 1, 1, 1, 0, 3, 3, 3, 3, 3, 1, 3,
#        0, 1, 6, 3, 3, 3, 3, 3, 2, 3, 0, 3, 1, 3, 3, 4, 1, 1, 5, 1, 0, 3,
#        1, 3, 3, 3, 3, 3, 0, 3, 3, 3, 6, 6, 3, 3, 1, 3, 1, 6, 1, 1, 0, 3,
#        3, 3, 1, 3, 2, 1, 0, 6, 3, 1, 6, 3, 1, 3, 3, 3, 3, 1, 3, 3, 1, 4,
#        3, 3, 4, 3, 3, 3, 3, 1, 4, 3, 3, 3, 3, 3, 2, 1, 1, 3, 3, 0, 3, 3,
#        3, 3, 6, 3, 3, 3, 2, 1, 3, 2, 6, 1, 3, 3, 2, 1, 1, 3, 1, 3, 3, 5,
#        3, 3, 4, 1, 5, 1, 3, 3, 3, 1, 3, 1, 1, 3, 3, 1, 3, 2, 1, 4, 1, 2,
#        3, 1, 2, 3, 4, 3, 1, 3, 2, 2, 3, 3, 3, 3, 3, 3, 3, 3, 1, 1, 2, 1,
#        3, 3, 3, 1, 3, 1, 3, 2, 3, 3, 3, 6, 3, 1, 5, 3], dtype=int64)

# %%
gcv.score(X_test_pca,y_test)
# Out:
# 0.748062015503876

# %% [markdown]
# 定义方法获取预测人名和真实人名

# %% [markdown]
# 调用方法获取人脸预测的名字，以及人脸的真实名字

# %% [markdown]
# 定义方法绘制人脸识别结果图形

# %%
# 将算法预测的结果显示一下，100张图片
X_test_pca.shape
# Out:
# (258, 300)

# %%
target_names
# Out:
# array(['Ariel Sharon', 'Colin Powell', 'Donald Rumsfeld', 'George W Bush',
#        'Gerhard Schroeder', 'Hugo Chavez', 'Tony Blair'], dtype='<U17')

# %%
plt.figure(figsize=(10*2,10*3))
for i in range(100):
    
    axes = plt.subplot(10,10,i+1)
#     X_test_pca -------> X_test一一对应的
    axes.imshow(X_test[i].reshape(125,94),cmap = 'gray')
    axes.axis('off')
    
#     t真实数据 y_test

    t = target_names[y_test[i]].split(' ')[-1]
    
#     p算法预测的数据y_
    p = target_names[y_[i]].split(' ')[-1]
    axes.set_title('True:%s\nPredict:%s'%(t,p))

# %%
# 样本是否均衡
np.unique(y_train)
# Out:
# array([0, 1, 2, 3, 4, 5, 6], dtype=int64)

# %%
for i in range(7):
    count = (y_train == i).sum()
    print(target_names[i],count)
# Out:
# Ariel Sharon 64
# Colin Powell 187
# Donald Rumsfeld 90
# George W Bush 416
# Gerhard Schroeder 86
# Hugo Chavez 63
# Tony Blair 124

# %%
from imblearn.over_sampling import SMOTE

# %%
smote = SMOTE()

smote.fit(X_train_pca,y_train)
# Out:
# SMOTE(k=None, k_neighbors=5, kind='regular', m=None, m_neighbors=10, n_jobs=1,
#    out_step=0.5, random_state=None, ratio='auto', svm_estimator=None)

# %%
# smote 均衡的时候，应该对人脸数据进行均衡
# 不是对降维之后的数据进行均衡
X_train_pca2,y_train2 = smote.sample(X_train_pca,y_train)

# %%
for i in range(7):
    count = (y_train2 == i).sum()
    print(target_names[i],count)
# Out:
# Ariel Sharon 416
# Colin Powell 416
# Donald Rumsfeld 416
# George W Bush 416
# Gerhard Schroeder 416
# Hugo Chavez 416
# Tony Blair 416

# %%
svc = SVC()

gcv = GridSearchCV(svc,param_grid={'C':[0.0001,0.01,0.1,1,10],'gamma':[0.0001,0.001,0.0033,0.01,0.1]})

# %time gcv.fit(X_train_pca2,y_train2)
# Out:
# Wall time: 5min 9s
# GridSearchCV(cv=None, error_score='raise',
#        estimator=SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False),
#        fit_params=None, iid=True, n_jobs=1,
#        param_grid={'C': [0.0001, 0.01, 0.1, 1, 10], 'gamma': [0.0001, 0.001, 0.0033, 0.01, 0.1]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=None, verbose=0)

# %%
gcv.best_params_
# Out:
# {'C': 10, 'gamma': 0.001}

# %%
gcv.best_score_
# Out:
# 0.9725274725274725

# %%
y_ = gcv.predict(X_test_pca)

# %%
gcv.score(X_test_pca,y_test)
# Out:
# 0.7829457364341085

# %%
X.shape
# Out:
# (1288, 11750)

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.2)

# %%
for i in range(7):
    
    print(target_names[i],(y_train == i).sum())
# Out:
# Ariel Sharon 60
# Colin Powell 193
# Donald Rumsfeld 94
# George W Bush 420
# Gerhard Schroeder 88
# Hugo Chavez 65
# Tony Blair 110

# %%
smote = SMOTE()

X_train2,y_train2 = smote.fit_sample(X_train,y_train)

# %%
X_train2.shape
# Out:
# (2940, 11750)

# %%
index = np.random.randint(3017,size = 1)[0]

img = X_train2[index].reshape(125,94)

plt.figure(figsize=(2,2))
plt.imshow(img,cmap = 'gray')

# %%
for i in range(7):
    
    print(target_names[i],(y_train2 == i).sum())
# Out:
# Ariel Sharon 420
# Colin Powell 420
# Donald Rumsfeld 420
# George W Bush 420
# Gerhard Schroeder 420
# Hugo Chavez 420
# Tony Blair 420

# %%
# X_train2,y_train2,作为训练数据
X_train2.shape
# Out:
# (2940, 11750)

# %%
pca = PCA(300,whiten=True)

pca.fit(X_train2)

X_train2_pca = pca.transform(X_train2)

# %%
svc = SVC(C = 10,gamma=0.001)

svc.fit(X_train2_pca,y_train2)
# Out:
# SVC(C=10, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma=0.001, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
# 预测
X_test.shape
# Out:
# (258, 11750)

# %%
X_test_pca = pca.transform(X_test)

svc.score(X_test_pca,y_test)
# Out:
# 0.8410852713178295

# %%
y_train
# Out:
# array([3, 3, 4, ..., 1, 3, 4], dtype=int64)

# %%
# SMOTE K近邻算法，创造人脸，算出来的，难免模糊


# 直接复制成431
for i in range(7):
    print(target_names[i],(y_train == i).sum())
# Out:
# Ariel Sharon 60
# Colin Powell 193
# Donald Rumsfeld 94
# George W Bush 420
# Gerhard Schroeder 88
# Hugo Chavez 65
# Tony Blair 110

# %%
cond = np.argwhere(y_train == 0).reshape(-1)

sharon = X_train[cond]

np.concatenate([sharon,sharon,sharon,sharon])
# Out:
# array([[ 83.666664,  82.333336,  81.      , ..., 218.      , 201.      ,
#         178.      ],
#        [ 27.      ,  25.      ,  27.333334, ..., 249.33333 , 245.33333 ,
#         249.33333 ],
#        [181.33333 , 180.33333 , 178.33333 , ...,  15.333333,  14.333333,
#          20.      ],
#        ...,
#        [ 84.      ,  84.      ,  83.666664, ..., 172.66667 , 171.33333 ,
#         172.66667 ],
#        [128.33333 , 120.      , 114.333336, ...,  21.666666,  18.333334,
#          15.666667],
#        [119.      , 142.      , 163.66667 , ..., 223.66667 , 237.66667 ,
#         246.66667 ]], dtype=float32)

# %%
56*7
# Out:
# 392

# %%
431//56 +1
# Out:
# 8

# %%
type(X_train)
# Out:
# numpy.ndarray

# %%
a = np.array([2,8])

# %%
np.concatenate([a]*3)
# Out:
# array([2, 8, 2, 8, 2, 8])

# %%
cond = np.argwhere(y_train == 0).ravel()

df = X_train[cond]
df.shape
# Out:
# (60, 11750)

# %%
result_data = []
result_label = []
for i in range(7):
    
    cond = np.argwhere(y_train == i).ravel()
    
    df = X_train[cond]
    
    df2 = y_train[cond]
    
    s = df.shape[0]
    c = 431//s + 1
    ret = np.concatenate([df]*c)[:431]
    ret2 = np.concatenate([df2]*c)[:431]
    result_data.append(ret)
    result_label.append(ret2)

# %%
len(result_data[4])
# Out:
# 431

# %%
len(result_label[0])
# Out:
# 431

# %%
X_train3 = np.concatenate([result_data[0],result_data[1],result_data[2],result_data[3],result_data[4],result_data[5],result_data[6]])

# %%
y_train3 = np.concatenate([result_label[0],result_label[1],result_label[2],result_label[3],result_label[4],result_label[5],result_label[6]])

# %%
for i in range(7):
    print(target_names[i],(y_train3 == i).sum())
# Out:
# Ariel Sharon 431
# Colin Powell 431
# Donald Rumsfeld 431
# George W Bush 431
# Gerhard Schroeder 431
# Hugo Chavez 431
# Tony Blair 431

# %%
pca = PCA(300,whiten=True)

# %%
# 测试数据X_test

# %%
pca.fit(np.concatenate([X_train3,X_test]))
# Out:
# PCA(copy=True, iterated_power='auto', n_components=300, random_state=None,
#   svd_solver='auto', tol=0.0, whiten=True)

# %%
X_train3_pca = pca.transform(X_train3)

X_test_pca = pca.transform(X_test)

# %%
svc = SVC(C = 10,gamma=0.001)

svc.fit(X_train3_pca,y_train3)
# Out:
# SVC(C=10, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma=0.001, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
svc.score(X_test_pca,y_test)
# Out:
# 0.8372093023255814

# %% [markdown]
# 调用方法，显示数据

# %% [markdown]
# 网络上查找图片使用机器学习模型进行预测

# %%
# 从网络下载图片
bush = plt.imread('bush.jpg')
plt.imshow(bush)

# %% [markdown]
# 读取网络数据进行灰度处理gray = [0.299,0.587,0.114]
# 如果是jpg图片进行归一化操作

# %%
bush2 = bush.max(-1)
plt.imshow(bush2,cmap='gray')

# %% [markdown]
# 如果图片尺寸不符合要求，那么修改尺寸

# %%
plt.figure(figsize=(2,2))
bush3 = bush2[55:210,90:200]
plt.imshow(bush3,cmap='gray')

# %%
bush3.shape
# Out:
# (155, 110)

# %%
from scipy import  ndimage as ndimage

# %%
plt.figure(figsize=(2,2))
bush4 = ndimage.zoom(bush3,zoom = [125/155,94/110])
plt.imshow(bush4,cmap='gray')
# Out:
# D:\ProgramData\Anaconda3\lib\site-packages\scipy\ndimage\interpolation.py:583: UserWarning: From scipy 0.13.0, the output shape of zoom() is calculated with round() instead of int() - for these inputs the size of the returned array has changed.
#   "the returned array has changed.", UserWarning)

# %%
X_test = bush4.reshape(1,-1)
X_test_pca = pca.transform(X_test)
svc.predict(X_test_pca)
# Out:
# array([6], dtype=int64)

# %%
target_names[6]
# Out:
# 'Tony Blair'
